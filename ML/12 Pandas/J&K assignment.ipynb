# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\parul\coding ninjas/ML/Pandas/terrorismData.csv')
df

# %%
jandk = df[df.State=='Jammu and Kashmir'].copy()

# %%
jandk.reset_index(drop=True, inplace=True)

# %%
jandk.head()
# Out:
#    Year  Month  Day Country              State      Region       City  \
# 0  1984      4   17   India  Jammu and Kashmir  South Asia      Bhela
# 1  1984      5   20   India  Jammu and Kashmir  South Asia      Jammu
# 2  1986     12   11   India  Jammu and Kashmir  South Asia     Madora
# 3  1988      1   21   India  Jammu and Kashmir  South Asia       Mand
# 4  1988      2    7   India  Jammu and Kashmir  South Asia  Kherawali
#
#     Latitude  Longitude         AttackType  Killed  Wounded  \
# 0  33.315527  74.622476      Assassination     2.0      0.0
# 1  32.726602  74.857026  Bombing/Explosion     1.0      0.0
# 2  33.934929  75.154160  Bombing/Explosion     1.0      5.0
# 3  32.888165  74.985168      Armed Assault     2.0      0.0
# 4  32.523889  74.974444      Armed Assault     4.0      5.0
#
#                                            Target Summary            Group  \
# 0  Gurbachan Singh Sandhar (Sikh lawyer) and wife     NaN  Sikh Extremists
# ...

# %%
jandk[jandk.Killed>0]
# Out:
#       Year  Month  Day Country              State      Region  \
# 0     1984      4   17   India  Jammu and Kashmir  South Asia
# 1     1984      5   20   India  Jammu and Kashmir  South Asia
# 2     1986     12   11   India  Jammu and Kashmir  South Asia
# 3     1988      1   21   India  Jammu and Kashmir  South Asia
# 4     1988      2    7   India  Jammu and Kashmir  South Asia
# ...    ...    ...  ...     ...                ...         ...
# 2437  2017     11   17   India  Jammu and Kashmir  South Asia
# 2439  2017     11   24   India  Jammu and Kashmir  South Asia
# 2445  2017     12    4   India  Jammu and Kashmir  South Asia
# 2449  2017     12   11   India  Jammu and Kashmir  South Asia
# 2453  2017     12   31   India  Jammu and Kashmir  South Asia
#
#                   City   Latitude  Longitude                   AttackType  \
# 0                Bhela  33.315527  74.622476                Assassination
# ...

# %%
KC=['Killed','City']

# %%
jandk[KC]
# Out:
#       Killed                City
# 0        2.0               Bhela
# 1        1.0               Jammu
# 2        1.0              Madora
# 3        2.0                Mand
# 4        4.0           Kherawali
# ...      ...                 ...
# 2449     2.0    Kralcheck Keller
# 2450     0.0  Baramulla district
# 2451     0.0    Pulwama district
# 2452     0.0            Srinagar
# 2453     8.0           Lethapora
#
# [2454 rows x 2 columns]

# %%
jandk[KC].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10904\3886445552.py in ?()
# ----> 1 jandk[KC].unique()
#
# D:\Anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
